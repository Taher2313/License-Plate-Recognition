# %%
import easyocr
import cv2
from PIL import Image
import pytesseract # also add tesseract to your path
import cv2

import numpy as np
import os
# %pylab inline
import matplotlib.pyplot as plt
from skimage import io
from skimage.color import rgb2gray
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
reader = easyocr.Reader(['en'])
ALPHANUMERIC = '0123456789QWERTYUIOPASDFGHJKLZXCVBNM'
# print(len(ALPHANUMERIC))
# print(pytesseract.get_languages())

def ocr1(img):
  return reader.readtext(detail=0, image=img, allowlist=ALPHANUMERIC)

# good psm options could be 6, 7, 13
def ocr2(img, psm=7):
  return pytesseract.image_to_string(image=img, lang='eng', config=f'--psm {psm} -c tessedit_char_whitelist={ALPHANUMERIC}')
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
def demo():
    directory = os.fsencode('./plates/')
        
    for file in os.listdir(directory):
        IMAGE_PATH = './plates/'+os.fsdecode(file)
        print(IMAGE_PATH)
        img = io.imread(IMAGE_PATH)
        io.imshow(img)
        io.show()

        print(ocr1(img))
        print(ocr2(img, 13))
        print(ocr2(img, 7))
        print(ocr2(img, 6))

# %%
# demo()
# Out:
# ./plates/1.jpg
# ['G4', 'JERSEY', 'GBJ', 'J98257', 'M', 'CF', 'J0IG']
# HT
#
# 7 525
#
# JERSEY
# CJ8F
# SBSPD
# WOGT
#
# SSNS
#
# ./plates/a.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11464/1790250070.py in <module>
# ----> 1 demo()
#
# ~\AppData\Local\Temp/ipykernel_11464/532645568.py in demo()
#       9         io.show()
#      10
# ---> 11         print(ocr1(img))
#      12         print(ocr2(img, 13))
#      13         print(ocr2(img, 7))
#
# ~\AppData\Local\Temp/ipykernel_11464/894027088.py in ocr1(img)
#       1 def ocr1(img):
# ----> 2   return reader.readtext(detail=0, image=img, allowlist=ALPHANUMERIC)
#
# ...
